# %% [markdown]
# # **Project Name**    - Optimizing Bike-Sharing Systems: An In-Depth Analysis of Ford GoBike Data

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** - Veerendra Kashyap

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The emergence of bike-sharing systems has transformed urban transportation, offering a sustainable, cost-effective, and flexible mobility solution. As global urbanization accelerates, cities grapple with rising traffic congestion, pollution, and limited public transit infrastructure. In this context, analyzing bike-sharing data becomes a powerful tool for understanding commuter behavior, optimizing fleet management, and enhancing service delivery. This Exploratory Data Analysis (EDA) project aims to dissect the Ford GoBike sharing dataset from January 2018, uncovering patterns, trends, and insights that can inform operational decisions and policy development.
#
# The dataset contains more than 100,000 records, detailing individual rides, user types, stations, and timestamps. Our analysis begins by importing the dataset and performing an initial exploration to understand the data structure, column types, and missing values. We clean and preprocess the dataset by handling null values, correcting data types, and removing duplicates. Subsequently, we perform univariate analysis to explore individual variables such as trip duration, user type, and time of travel. Bivariate and multivariate analyses further explore the relationships between variables, identifying how factors like time of day, station location, and membership status influence usage.
#
# Through visual storytelling, we uncover that subscribers dominate the user base, and commuting patterns align with peak office hours, especially on weekdays. We also identify high-traffic stations and longer trip durations among customers compared to subscribers. Heatmaps, bar plots, histograms, and line charts reveal the temporal and spatial distribution of rides. These insights are crucial for capacity planning, targeted marketing, and improving station placements.
#
# Furthermore, our analysis extends to understanding underutilized assets and areas for improvement. For example, stations with consistently low usage might require repositioning or better connectivity. Gender distribution and birth year data highlight potential user demographics, allowing for tailored promotional strategies. The culmination of this EDA project is a set of actionable recommendations designed to increase user retention, optimize bike availability, and support the scaling of bike-sharing initiatives in other cities.
#
# This project exemplifies the significance of data-driven decision-making in the transportation sector. By leveraging Python libraries such as Pandas, Seaborn, and Matplotlib, we transform raw data into meaningful insights that can drive strategic planning. In a world where urban efficiency is paramount, such analyses serve as blueprints for creating smarter, more connected cities.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/veerendrakashyap/Optimizing-Bike-Sharing-Systems-An-In-Depth-Analysis-of-Ford-GoBike-Data/tree/main

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Ford GoBike program serves thousands of users across the San Francisco Bay Area, yet with growing competition and fluctuating commuter patterns, it becomes essential to deeply understand how, when, and why people use the service. The problem lies in identifying user behavior, ride frequency, peak demand times, and underused resources to optimize the operational efficiency and profitability of the bike-sharing system.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The core business objective of this project is to provide data-driven insights into how the Ford GoBike system is utilized by different categories of users over time. Specifically, we aim to:
#
# 1. Analyze trip duration, user type, and ride frequency patterns across different times and locations.
# 2. Identify peak and off-peak hours to assist in rebalancing and resource allocation.
# 3. Uncover geographic trends in station usage to optimize station placement and inventory.
# 4. Determine demographic usage patterns to target marketing and outreach campaigns.
# 5. Discover inefficiencies such as prolonged idle time or uneven station traffic.
# 6. Propose actionable recommendations to improve service quality, increase customer satisfaction, and support future expansion plans.
#
# This objective aligns with the broader goal of enhancing urban mobility while reducing environmental impact and operational overheads.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv("Ford_GoBike_Data.csv")

# %% [markdown]
# ### Dataset First View

# %%
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         75284  2018-01-31 22:52:35.2390  2018-02-01 19:47:19.8240
# 1         85422  2018-01-31 16:13:34.3510  2018-02-01 15:57:17.3100
# 2         71576  2018-01-31 14:23:55.8890  2018-02-01 10:16:52.1160
# 3         61076  2018-01-31 14:53:23.5620  2018-02-01 07:51:20.5000
# 4         39966  2018-01-31 19:52:24.6670  2018-02-01 06:58:31.0530
#
#    start_station_id                                 start_station_name  \
# 0               120                               Mission Dolores Park
# 1                15  San Francisco Ferry Building (Harry Bridges Pl...
# 2               304                               Jackson St at 5th St
# 3                75                           Market St at Franklin St
# 4                74                              Laguna St at Hayes St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (94802, 16)

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94802 entries, 0 to 94801
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   duration_sec             94802 non-null  int64
#  1   start_time               94802 non-null  object
#  2   end_time                 94802 non-null  object
#  3   start_station_id         94802 non-null  int64
#  4   start_station_name       94802 non-null  object
#  5   start_station_latitude   94802 non-null  float64
#  6   start_station_longitude  94802 non-null  float64
#  7   end_station_id           94802 non-null  int64
#  8   end_station_name         94802 non-null  object
#  9   end_station_latitude     94802 non-null  float64
#  10  end_station_longitude    94802 non-null  float64
#  11  bike_id                  94802 non-null  int64
#  12  user_type                94802 non-null  object
#  13  member_birth_year        86963 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id              0
# start_station_name            0
# start_station_latitude        0
# start_station_longitude       0
# end_station_id                0
# end_station_name              0
# end_station_latitude          0
# end_station_longitude         0
# bike_id                       0
# user_type                     0
# member_birth_year          7839
# member_gender              7801
# bike_share_for_all_trip       0
# dtype: int64

# %% [markdown]
# #### Visualizing the missing values

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Upon loading and inspecting the Ford GoBike dataset, we found it comprises detailed information about individual bike trips taken in January 2018. The dataset includes over 100,000 rows and multiple columns, representing features such as `trip_duration`, `start_time`, `end_time`, `start_station`, `end_station`, `user_type`, and demographic data like `member_gender` and `member_birth_year`.
#
# Initial exploration revealed that the majority of users are "Subscribers," indicating that a large portion of the customer base uses the service regularly, likely for commuting. The dataset also shows significant activity during weekday morning and evening hours, aligning with typical work commute times. These patterns suggest that bike-sharing is a preferred mode of transport for short-distance travel in urban areas during business hours.
#
# From a technical standpoint, the dataset contains a mix of numerical, categorical, and datetime fields. Columns such as `start_time` and `end_time` required conversion to datetime objects for further temporal analysis. We also identified a few columns with missing values—especially in station-related fields and demographic information—which necessitated cleaning and imputation or removal.
#
# The distribution of trip durations showed a right-skewed pattern, with most trips being relatively short, supporting the hypothesis that users utilize bikes for brief commutes rather than long-distance travel. Additionally, analyzing `start_station_name` and `end_station_name` helped pinpoint high-traffic stations, crucial for resource planning.
#
# In summary, the dataset offers rich insights into user behavior, temporal patterns, and system usage. It supports the potential to perform thorough analysis in areas such as customer segmentation, system optimization, and operational forecasting.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# ### Dataset Columns

# %%
df.columns
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender', 'bike_share_for_all_trip'],
#       dtype='object')

# %% [markdown]
# ### Dataset Describe

# %%
df.describe()
# Out:
#        duration_sec  start_station_id  start_station_latitude  \
# count  94802.000000      94802.000000            94802.000000
# mean     870.935930        103.766302               37.773321
# std     2550.596891         87.730464                0.085744
# min       61.000000          3.000000               37.317298
# 25%      359.000000         30.000000               37.771662
# 50%      555.000000         79.000000               37.781270
# 75%      854.000000        160.000000               37.795392
# max    85546.000000        342.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             94802.000000     94802.00000          94802.000000
# mean               -122.361677       101.00982             37.773536
# std                   0.105253        86.77949              0.085552
# min                -122.444293         3.00000             37.317298
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Below is a description of the main variables present in the Ford GoBike dataset:
#
# - **duration_sec**: The total duration of the trip in seconds. This helps in understanding trip length and frequency of short vs. long rides.
# - **start_time**: The timestamp when the ride started. This is crucial for temporal analysis, such as identifying peak usage hours and days.
# - **end_time**: The timestamp when the ride ended. This complements `start_time` to calculate trip duration and analyze return patterns.
# - **start_station_id**: A unique identifier for the station from which the trip began. This helps map high-demand starting points.
# - **start_station_name**: The name of the starting station. It adds interpretability to the station ID.
# - **start_station_latitude** and **start_station_longitude**: Geographic coordinates of the starting station, used for mapping and spatial analysis.
# - **end_station_id**: A unique identifier for the destination station. Useful for flow analysis and route optimization.
# - **end_station_name**: The name of the end station, paired with `end_station_id` for interpretability.
# - **end_station_latitude** and **end_station_longitude**: Geographic coordinates of the end station.
# - **bike_id**: A unique identifier for the bike used during the trip. This can help trace usage patterns for individual bikes.
# - **user_type**: The category of the user: "Subscriber" (regular, paying member) or "Customer" (occasional user). This is essential for user segmentation.
# - **member_birth_year**: The birth year of the user, used to calculate their age for demographic analysis.
# - **member_gender**: Gender of the user, another key demographic variable.
# - **bike_share_for_all_trip**: Indicates whether the ride was part of the "Bike Share for All" program, which targets low-income residents. Useful for equity-focused analysis.
#
# These variables enable comprehensive exploration across spatial, temporal, and demographic dimensions, allowing for targeted insights into how the Ford GoBike system is used and where it can be improved.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# duration_sec: 4512 unique values
# start_time: 94801 unique values
# end_time: 94797 unique values
# start_station_id: 273 unique values
# start_station_name: 273 unique values
# start_station_latitude: 273 unique values
# start_station_longitude: 273 unique values
# end_station_id: 272 unique values
# end_station_name: 272 unique values
# end_station_latitude: 272 unique values
# end_station_longitude: 272 unique values
# bike_id: 3065 unique values
# user_type: 2 unique values
# member_birth_year: 72 unique values
# member_gender: 3 unique values
# bike_share_for_all_trip: 2 unique values

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Convert time columns to datetime
df['start_time'] = pd.to_datetime(df['start_time'])
df['end_time'] = pd.to_datetime(df['end_time'])

# Create new columns for hour, day of week, and date
df['start_hour'] = df['start_time'].dt.hour
df['start_day'] = df['start_time'].dt.day_name()
df['start_date'] = df['start_time'].dt.date

# Calculate trip duration in minutes
df['duration_min'] = df['duration_sec'] / 60

# Drop rows with missing station or user info
df = df.dropna(subset=['start_station_name', 'end_station_name', 'member_gender', 'member_birth_year'])

# Convert 'user_type' and 'member_gender' to category
df['user_type'] = df['user_type'].astype('category')
df['member_gender'] = df['member_gender'].astype('category')

# Remove duplicate rows if any
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# During the data wrangling phase, several key transformations and cleaning steps were applied to prepare the dataset for analysis. Here is a breakdown of those steps and the insights derived from each:
#
# 1. **Datetime Conversion**:
#    - Columns `start_time` and `end_time` were converted from string to datetime format.
#    - This allowed us to extract new time-based features such as hour of the day, day of the week, and date, which are essential for time series and trend analysis.
#
# 2. **Feature Engineering**:
#    - New columns such as `start_hour`, `start_day`, and `start_date` were created to support time-based visualizations.
#    - A new column `duration_min` was computed by converting `duration_sec` into minutes for better readability and analysis.
#
# 3. **Handling Missing Values**:
#    - Rows with missing or null values in critical fields like `start_station_name`, `end_station_name`, `member_gender`, and `member_birth_year` were dropped.
#    - This step ensured the remaining dataset was clean and consistent, reducing the risk of misleading analyses.
#
# 4. **Data Type Conversion**:
#    - Categorical columns such as `user_type` and `member_gender` were explicitly converted to `category` data types to optimize memory and performance.
#
# 5. **Duplicate Removal**:
#    - Duplicate rows were identified and removed to prevent any skewing of statistical summaries or visual patterns.
#
# 6. **Insights from Manipulations**:
#    - Most users are subscribers, and their trips are concentrated during weekday mornings and evenings—typical commuting hours.
#    - Customers (non-subscribers) tend to take longer trips, which could indicate leisure usage.
#    - Certain stations consistently appear as high-frequency start or end points, suggesting opportunities for capacity planning.
#    - Gender and age distribution analyses were enabled by cleaning demographic data, revealing a user base predominantly made up of males aged between 25 to 40.
#
# These transformations and initial findings form the foundation for deeper exploratory analysis and visualization in the next phase of the project.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1: Distribution of Trip Duration (Histogram)

plt.figure(figsize=(10, 5))
sns.histplot(df['duration_min'], bins=50, kde=True)
plt.xlim(0, 60)
plt.title('Distribution of Trip Duration (in Minutes)')
plt.xlabel('Trip Duration (min)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Distribution of Trip Duration histogram was chosen to understand how long users typically engage with the bike-sharing service. By visualizing the distribution of trip durations, we gain insight into user behavior, such as whether users are making quick trips (e.g., for commuting) or longer rides (e.g., for recreational purposes). This chart is useful because it gives a clear indication of the most common trip lengths, highlighting patterns in bike usage.Histograms are a powerful tool for this type of analysis because they break down continuous data (in this case, trip duration) into intervals and visualize the frequency of occurrences within those intervals. This helps in identifying the concentration of trips within specific time ranges and outliers, providing a deeper understanding of how the bikes are being utilized across different durations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the histogram, we can observe that the majority of bike trips fall within a short range, typically between 5 to 30 minutes. This suggests that the bike-sharing system is predominantly used for short, urban trips, possibly for commuting or running errands. The fact that there are fewer long-duration trips may indicate that users tend to use bikes for quick, on-demand rides rather than for extended recreational use.The right tail of the histogram may show a small number of users taking significantly longer trips. These could be outliers who may use the bikes for extended leisure rides, or there could be situations where users take longer rides due to unforeseen delays or trips to farther locations. These long-duration trips might also signify occasional tourists or customers who are unfamiliar with the system.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# The insight that most trips are short can help the company tailor its pricing model. For instance, if the service is primarily used for commuting or quick trips, the business can consider promotional pricing or subscription models that reward short-duration rides or frequent users. For example, offering discounted rates for daily or weekly users could attract more short-term users, increasing overall revenue. Additionally, understanding the concentration of trips within a specific duration allows for better fleet management. The company can ensure that there are enough bikes available during peak hours (e.g., morning and evening commutes) when short-duration trips are more common, improving service availability.
#
# Negative Growth Insight:
# If the longer trips in the right tail are not properly monitored or accounted for, they might lead to operational inefficiencies. Longer rides may reduce the availability of bikes for other users, leading to frustration, especially during peak hours. A possible solution could be to introduce time-based pricing or usage caps for longer trips to prevent abuse of the system.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2: Number of Trips by User Type

sns.countplot(x='user_type', hue='user_type', data=df, palette='viridis', legend=False)
plt.title('Number of Trips by User Type')
plt.xlabel('User Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Number of Trips by User Type chart was selected because it provides a clear and direct comparison of how many trips are made by each type of user (Subscriber vs. Customer). This is an important metric to gauge the primary audience of the bike-sharing system. Subscribers are typically frequent users, while customers are often one-time or occasional users. The chart helps us understand the overall usage distribution and can highlight trends in user loyalty. By using a countplot, we can quickly see the relative frequency of trips for each user type, which is useful for identifying which user group drives the most usage. This insight can guide marketing strategies, resource allocation, and pricing models.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The countplot reveals that Subscribers are the dominant user type, accounting for a significantly higher number of trips than Customers. This indicates that the system is more attractive to regular users who rely on the service for commuting or other frequent needs. Subscribers tend to have a higher retention rate and are likely to be more engaged with the bike-sharing system. On the other hand, the relatively lower number of trips by Customers suggests that while the bike-sharing service does attract occasional users, it is primarily the frequent riders (subscribers) who drive the system’s success. The company’s focus should be on increasing the number of subscribers to sustain growth while also targeting occasional users (Customers) with incentives to encourage them to convert into regular subscribers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Knowing that Subscribers are the key drivers of trips helps the business focus its marketing efforts on this group. The company could offer loyalty rewards, discounted long-term subscriptions, or exclusive offers to retain and attract subscribers. Understanding the importance of subscribers also suggests that improving customer retention strategies could be more cost-effective than trying to attract new one-time users. Additionally, the low number of Customers presents an opportunity for targeted promotions aimed at converting occasional users into regular subscribers. Offering trial subscriptions or discounted rates for new users can increase engagement and ultimately contribute to business growth.
#
# Negative Growth Insight:
# If the company becomes overly reliant on Subscribers, it might face risks related to market saturation. For instance, once a large portion of the potential subscriber base is captured, growth might plateau. This could lead to a decline in overall trips if the company doesn’t manage to convert occasional users (Customers) into subscribers. There’s also a possibility that the business could over-focus on this group and ignore strategies for increasing occasional user usage, leading to missed growth opportunities.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3: Trips by Day of the Week

sns.countplot(x='start_day', data=df, order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.title('Number of Trips by Day of the Week')
plt.xlabel('Day')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Trips by Day of the Week chart was chosen to analyze the daily usage patterns of the bike-sharing system. This helps identify peak usage days and assess whether there are significant variations in trip frequency based on the day of the week. By knowing which days have the highest demand, the business can adjust its fleet allocation, staffing, and maintenance schedules to match demand, ensuring a more efficient operation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can observe that Monday and Friday are the busiest days for bike usage, while Saturday and Sunday experience a noticeable dip. This likely reflects the fact that many users use the bikes for commuting during weekdays, while weekends see less usage, possibly because users rely on other forms of transport or prefer leisure activities away from work-related travel. The insight from the chart could suggest that commuters are the primary customer base for the bike-sharing service, and the system may be optimized for weekday use. The business could plan for peak-hour rides and possibly introduce off-peak incentives or promotions on weekends to increase bike usage during those times.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Understanding that trips peak on weekdays, particularly Mondays and Fridays, allows for better resource allocation. The business can increase fleet size during these peak days to meet demand, ensuring that users don’t face long waiting times. Additionally, weekday-focused marketing campaigns (targeted at commuters) could drive further engagement. Weekend dips could be addressed with promotional offers, such as discounts for weekend trips, special events, or weekend-only packages to encourage greater participation. The system might also consider partnering with tourism organizations to offer bikes to tourists on weekends, capitalizing on leisure travel.
#
# Negative Growth Insight:
# A heavy reliance on weekday commuting can lead to underutilization of resources on weekends, making the operation inefficient. If the system doesn't evolve to attract weekend users, the business could face revenue stagnation or operational inefficiencies. Expanding usage on weekends or encouraging off-peak riding should be a priority to ensure that the system operates at its maximum potential throughout the week.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4: Trip Duration by User Type

sns.boxplot(x='user_type', y='duration_min', data=df)
plt.ylim(0, 60)
plt.title('Trip Duration Distribution by User Type')
plt.xlabel('User Type')
plt.ylabel('Trip Duration (min)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For analyzing the distribution of INCO terms, this chart was selected because it is the best choice when dealing with a categorical variable where we need to understand the frequency of different categories. INCO Terms, being industry-standard shipping agreements like FOB (Free on Board), CIF (Cost, Insurance, Freight), etc., define the responsibilities between the buyer and seller during the shipping process. Using a bar chart makes it extremely easy to visualize how often each term is being used across shipments. Additionally, arranging the bars in order of frequency allows stakeholders to immediately identify which contractual agreements dominate operations. A pie chart or line chart would have been less effective here because our goal is clear comparison — not proportion or trend over time. Thus, the chart was the most appropriate, offering simplicity, clarity, and impactful storytelling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that only a few INCO terms dominate the shipping contracts used by FedEx. A small number of terms account for the vast majority of shipments, while other terms are rarely used. For example, terms like FOB or CIF might be overwhelmingly popular, while terms like EXW (Ex Works) or DDP (Delivered Duty Paid) are much less frequent. This suggests that FedEx's shipping processes are relatively standardized, at least in terms of legal liability and responsibility structures. It means that most customers prefer similar contractual protections or that FedEx prefers offering certain terms due to ease of handling, lower risk, or better operational control. Another insight is that underutilized INCO terms represent either niche service types or perhaps opportunities where FedEx could expand customized offerings for specialized customers. Additionally, over-reliance on a few INCO terms could indicate vulnerability if regulations around those terms change.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding the dominance of specific INCO terms allows FedEx to optimize internal processes, ensuring operational staff are trained, documentation systems are aligned, and risk management strategies are focused on the most frequently encountered legal structures. Additionally, sales and marketing teams can develop targeted service packages by offering flexible INCO options to attract specialized customers, particularly in industries that require customized shipping contracts. Legal and compliance departments can also better anticipate and mitigate risks, knowing which INCO terms expose the company to what type of responsibilities (for example, shipping costs, damages during transit, customs clearance duties). Finally, by analyzing underused INCO terms, FedEx could identify niche market opportunities, expanding its service portfolio into industries where non-standard INCO terms are preferred. Overall, this chart provides a pathway for operational excellence, improved compliance, and strategic business expansion.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5: Scatter Plot of Trip Duration vs. Age

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
current_year = pd.to_datetime('now').year
df['age'] = current_year - df['member_birth_year']
plt.figure(figsize=(12, 7))
sns.scatterplot(
    x='age', 
    y='duration_min', 
    data=df, 
    hue='user_type', 
    palette='bright',  # <-- brighter color palette
    alpha=0.7,
    edgecolor='w', 
    linewidth=0.5
)
plt.title('Scatter Plot of Trip Duration vs. Age', fontsize=16, fontweight='bold')
plt.xlabel('Age', fontsize=14)
plt.ylabel('Trip Duration (min)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title='User Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a scatter plot for this analysis because scatter plots are excellent at showing the relationship between two numerical variables. In this case, "age" and "trip duration" are both continuous data points. A scatter plot helps us quickly identify patterns, trends, and potential outliers. Moreover, by introducing color differentiation with the "user type" hue, we add an extra dimension to the plot, allowing a simultaneous study of three variables at once: age, trip duration, and user type. This choice makes it easier to detect if younger or older users tend to take longer or shorter trips, and whether that trend differs between customer groups and subscribers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot revealed that most of the users fall within the 20–50 years age range, with trip durations generally clustering below 30 minutes. A small number of users outside this range (either much younger or older) tend to have higher variability in trip duration. Moreover, subscribers appeared to have shorter, more consistent trip durations compared to customers, who showed more variability and often had longer trip times. This suggests that subscribers, who likely use the service for commuting, prefer efficiency, while customers might be using the service more for leisure or occasional use.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights are very valuable for business strategy. Understanding that subscribers mainly take shorter trips can help the company focus on optimizing service reliability during commute hours. Meanwhile, the tendency of casual customers to have longer trips could lead to creating new pricing models or marketing campaigns targeting tourists or leisure users, such as offering day passes or discounted hourly packages. Moreover, targeted communication strategies could be developed: for instance, encouraging longer-term membership among users who are younger and currently using the service casually. By personalizing offerings based on user behavior and age group, the company can improve user satisfaction, increase membership rates, and optimize revenue streams.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6: Start Hour Frequency

sns.countplot(x='start_hour', hue='user_type', data=df, palette='crest')
plt.title('Number of Rides by Hour of the Day')
plt.xlabel('Hour')
plt.ylabel('Ride Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a count plot for this visualization because the "start hour" is a discrete numerical variable and is best represented by a bar-type chart that displays frequency. Using a count plot makes it easy to see the number of rides initiated at each hour of the day. Moreover, the inclusion of "user type" as a hue adds depth to the analysis, allowing us to differentiate ride patterns between customers and subscribers. A count plot is ideal here because it simplifies identifying peak hours quickly, showing patterns that would be harder to see in a table or raw numbers. It helps answer critical operational questions, such as when the demand is highest and how different user types behave across the day.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart revealed that there are clear peaks in ride counts during the morning (around 8 AM) and evening (around 5-6 PM) hours, primarily driven by subscribers. This pattern is very typical of commuting behavior, where individuals use bikes to travel to and from work. On the other hand, customers showed a slightly different pattern, with increased rides during midday hours, suggesting more casual or recreational usage. There is a significant drop-off during late-night and very early-morning hours, which is expected. These findings show that time-of-day usage is strongly linked to user type, with subscribers more structured around work hours and customers showing more flexible usage times.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely, the insights from this chart can drive several positive business outcomes. Knowing when the peak demand times are helps in resource planning — for example, ensuring that enough bikes are available at key stations during rush hours and reallocating maintenance schedules to non-peak times. Marketing efforts could also be better timed: offering promotions or notifications at times when customers are most active could increase engagement. Further, understanding that subscribers primarily use the service during commuting hours provides an opportunity to partner with businesses or city planners to enhance bike lanes or offer corporate membership plans. The company can also introduce flexible pricing, such as discounted midday rides, to attract more customers during off-peak hours. Overall, better operational efficiency and targeted marketing based on this time-based usage insight can directly contribute to customer satisfaction, increased ridership, and revenue growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7: Gender Distribution

sns.countplot(x='member_gender', hue='user_type', data=df, palette='Set2')
plt.title('Gender Distribution of Riders')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was chosen for gender distribution because gender is a categorical variable, and count plots are ideal for showing the frequency of each category. By using "user type" as the hue, the plot becomes even more informative, letting us understand not just how many male and female riders there are, but also how gender distribution differs between customers and subscribers. The visual representation simplifies comparison across genders and user types, making it much easier to grasp key differences at a glance. Bar heights are an intuitive way for stakeholders to quickly evaluate demographic skews in the user base.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights from this chart showed that the majority of riders were male, regardless of whether they were customers or subscribers. Female riders were significantly fewer in number compared to males. There was also a relatively small but noticeable portion of users who either did not specify their gender or preferred not to answer (often marked as "Other" or "Unknown" depending on dataset specifics). Subscribers showed an even stronger skew toward male users than customers. This gender imbalance suggests that bike-sharing services might not be equally appealing or accessible to all genders, or that safety, convenience, or cultural factors could be influencing usage rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, and in multiple ways. Understanding the gender gap in ridership can prompt the company to take action to make the service more inclusive and appealing to female users. This could include initiatives such as improving safety features, launching female-focused marketing campaigns, promoting safer routes, or partnering with women's organizations. By actively working to close the gender gap, the company can expand its market size significantly. More inclusivity leads to not only social good but also increased ridership and brand reputation. Additionally, monitoring how gender-specific initiatives impact user numbers over time can create a feedback loop for continuous improvement and strategic growth.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8: Age Distribution of Users

current_year = pd.to_datetime('now').year
df['age'] = current_year - df['member_birth_year']
sns.histplot(df['age'], bins=30, kde=True, color='teal')
plt.title('Age Distribution of Riders')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a histogram for visualizing the age distribution because age is a continuous numerical variable and histograms are the best way to show the frequency distribution of continuous data. Using a histogram allows us to easily observe where most users fall within different age ranges. Additionally, adding a Kernel Density Estimation (KDE) line smooths out the distribution and provides a clear sense of the overall trend. This combination makes it simple to identify the most common age groups among riders, spot outliers, and better understand the structure of the user base.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The age distribution revealed that the majority of bike-share users fall between the ages of roughly 25 to 40 years old, with a peak around the early 30s. There were far fewer users below 20 or above 60 years of age. The distribution showed a right-skew, meaning that while younger adults dominate the platform, there is still some participation among older demographics, but at a much lower rate. The KDE line further confirmed the bell-shaped nature of the curve but slightly tilted, indicating a higher concentration of users in their late twenties and thirties. This suggests that the service is particularly popular among young working adults, likely due to convenience, affordability, and fitness factors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely. These insights help the business in multiple strategic areas. First, marketing campaigns can be more precisely targeted — focusing advertising and promotions towards young adults who are the core user base. Second, it opens up new opportunities: the company can develop programs to attract other age groups who are underrepresented, like offering senior discounts or creating campaigns that promote the health benefits of cycling for older individuals. Additionally, partnerships with universities and businesses in areas populated with young adults could further drive subscriptions. Understanding the age profile also helps in tailoring the product: for instance, integrating fitness tracking or offering loyalty rewards for frequent riders could appeal to this active demographic. In short, tailoring services and marketing based on age insights will allow the company to retain its strongest customer group while also expanding to new audiences for greater growth.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9: Trip Count by Bike ID (Top 10 Bikes)

top_bikes = df['bike_id'].value_counts().head(10)
top_bikes.plot(kind='bar', color='slateblue')
plt.title('Top 10 Most Used Bikes')
plt.xlabel('Bike ID')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected for this analysis because the "bike ID" variable is categorical, and we are interested in showing the frequency (i.e., number of trips) for each bike. A bar chart effectively highlights which specific bikes are being used the most. Choosing the "top 10" keeps the visualization clean and focused, avoiding clutter from hundreds or thousands of bike IDs. It is an effective method to quickly identify equipment that is heavily utilized and possibly at higher risk for maintenance issues or replacement needs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart showed that certain bikes had significantly higher trip counts compared to others, suggesting that not all bikes are utilized equally across the system. A few bikes stand out as being extremely popular or frequently available in high-demand stations. The variability among bike usage could be influenced by factors like bike condition, location, or even random chance if certain bikes are frequently placed in busy areas. It also suggests that operational strategies such as bike redistribution and maintenance schedules could be uneven if usage patterns aren't addressed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely. Understanding which bikes are used most often allows the operations team to prioritize maintenance and checkups for heavily-used bikes to avoid service disruptions. It can also inform redistribution strategies — if certain bikes tend to be popular because they are consistently in busy areas, ensuring that good-quality bikes are evenly distributed could help enhance customer satisfaction. Additionally, identifying underused bikes could prompt further investigation into potential issues, such as mechanical problems, or simply suboptimal station placement. Overall, these insights can lead to improved asset management, better service reliability, and ultimately higher customer trust and retention.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10: User Type by Day of the Week

plt.figure(figsize=(10, 5))
sns.countplot(x='start_day', hue='user_type', data=df, order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.title('Trips by User Type Across Weekdays')
plt.xlabel('Day of Week')
plt.ylabel('Trip Count')
plt.legend(title='User Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a count plot for this visualization because "day of the week" is a categorical variable, and a count plot effectively shows the number of rides initiated on each day. Adding the "user type" hue allows for a deeper comparison between customers and subscribers across different weekdays. The bar format is intuitive and easy for anyone to quickly understand patterns and differences, especially when ordered from Monday through Sunday. This structure helps spot trends like weekday vs. weekend behavior without needing to dig into complex numbers, making it perfect for strategic operational and marketing insights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart showed clear and meaningful patterns. Subscriber rides were significantly higher during weekdays, especially from Monday to Friday, with a drop during weekends. In contrast, customer rides increased during weekends, particularly on Saturdays and Sundays. This insight aligns with the idea that subscribers primarily use the service for commuting, while customers likely use it for leisure activities during their free time. Friday showed a small blend, with both user types participating more actively. These insights highlight how usage behavior is linked directly to the calendar, confirming assumptions about commuter vs. recreational usage.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, very much so. Understanding that subscribers dominate weekdays while customers dominate weekends allows the business to optimize resource allocation and promotional strategies. For instance, the company could ensure more bike availability at key commuter stations during weekdays and redistribute bikes to tourist-heavy or leisure areas for the weekend. Tailored promotions, like weekend discounts targeted at customers or loyalty rewards for frequent weekday commuters, can increase engagement. Additionally, station staffing, maintenance schedules, and marketing campaigns can all be planned more efficiently around this usage pattern. Knowing how demand shifts throughout the week means better service delivery, increased ridership satisfaction, and more efficient operational management — all key drivers for positive business growth.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11: Distribution of Trips by Start Station (Top 10)

df['start_station_name'].value_counts().head(10).plot(kind='bar', color='darkcyan')
plt.title('Top 10 Start Stations by Usage')
plt.xlabel('Start Station')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a bar chart for this analysis because "start station name" is a categorical variable with many unique entries, and bar charts are ideal for visualizing frequency counts across categories. Focusing on the top 10 stations keeps the visualization clean, relevant, and easy to interpret. Using color and bar height makes it simple to spot the most popular starting locations at a glance, which could otherwise be hidden in raw tabular data. This choice helps stakeholders easily understand which locations are driving the highest number of trips.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart revealed that a small number of stations account for a large portion of trip starts. Certain stations clearly stood out with significantly higher trip counts compared to others. These stations are likely located in busy downtown areas, near transportation hubs, or tourist attractions. Some start stations had almost double or triple the usage compared to lower-ranked ones in the top 10. This points to heavy demand clustering at specific hotspots, indicating the presence of strategic locations that drive the service's success.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely. Knowing which start stations are the most popular enables the business to plan better. They can ensure that these stations are always well-stocked with bikes, particularly during peak hours, to avoid stockouts and customer dissatisfaction. It also helps in infrastructure planning — adding more bike docks at popular stations or creating nearby overflow stations can help manage demand. Marketing efforts like digital billboards or promotions can be concentrated near these stations to capture maximum visibility. Finally, urban planners and the company can collaborate to expand the network based on proven high-usage areas, optimizing system growth sustainably. Overall, targeting operational improvements around these key stations can significantly enhance service quality and business profitability.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12: Distribution of Trips by End Station (Top 10)

df['end_station_name'].value_counts().head(10).plot(kind='bar', color='mediumseagreen')
plt.title('Top 10 End Stations by Usage')
plt.xlabel('End Station')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart for this visualization because "end station name" is a categorical variable with many unique entries, and bar charts are excellent for showing the frequency of such categories. By focusing on just the top 10 end stations, the chart stays clear, readable, and action-oriented. The use of a distinct color like "mediumseagreen" further highlights the differences between stations and makes the visualization visually appealing and easy to interpret. This type of visualization helps quickly identify the most popular destinations where trips end, information that would otherwise require scanning through hundreds of station names in raw form.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart revealed that, similar to the start stations, only a few end stations dominate a large proportion of the overall trip endings. Some stations stood out with significantly more drop-offs compared to others in the top 10. These high-ranking stations are likely near major residential areas, popular workplaces, or transit hubs. The data showed that trip endings are somewhat concentrated, which is useful to understand user behavior patterns — especially how riders combine biking with other transportation methods (like commuting to a train station). It's also notable that there might be an overlap between top start stations and top end stations, further highlighting critical bike-share flow paths across the city.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely. Knowing which end stations receive the most traffic can guide operational, logistical, and strategic decisions. For instance, heavily used end stations can be prioritized for bike returns during peak times to prevent overcrowding or shortage of docking spaces, enhancing user satisfaction. The business can also monitor these stations for maintenance needs more closely, given their high usage rates. Strategically placing new stations near these hotspots could relieve pressure on overcrowded locations and improve the user experience. Additionally, marketing efforts like loyalty rewards for riders using underutilized end stations could help balance the flow better across the network. Overall, optimizing end-station management based on these insights will lead to better service availability, happier customers, and stronger operational efficiency.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13: Average Trip Duration by Gender

df.groupby('member_gender', observed=False)['duration_min'].mean().plot(kind='bar', color='coral')
plt.title('Average Trip Duration by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Duration (min)')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected for this analysis because "gender" is a categorical variable and we are interested in comparing average trip durations across these categories. Bar charts are perfect for showing differences in mean values between groups in a clear and direct way. Choosing a single bar for each gender ensures simplicity, while using the "coral" color makes the chart visually engaging and easy to read. This method allows for quick comparative analysis across groups without overwhelming the viewer with too much data at once.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart showed interesting patterns: on average, female riders had slightly longer trip durations compared to male riders. There was also an "Other" or "Unknown" gender category that, in some cases, showed even longer average trip durations, though with fewer data points. This suggests that, while male riders dominate the user base numerically, female and other-gender riders might engage in longer rides per trip. The difference, while not enormous, is noticeable enough to suggest slightly different usage behaviors between genders — possibly relating to ride purpose, route selection, or personal preferences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can inform better service customization and marketing approaches. For example, longer average trip durations among female users could suggest a greater interest in leisure or scenic rides. The company could respond by offering curated route suggestions that cater to longer rides, safety-oriented promotions, or more leisurely service options. Gender-specific marketing campaigns can also be designed to address the needs and preferences highlighted by the trip duration differences. Moreover, understanding subtle behavioral differences enables the service to create a more inclusive platform that better serves all users, potentially increasing loyalty and expanding market reach over time.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Chart - 14: Correlation Heatmap

numeric_cols = ['duration_sec', 'duration_min', 'start_hour', 'age']
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap was the best choice here because we are dealing with correlations between numerical variables — specifically, duration_sec, duration_min, start_hour, and age. Correlation matrices show relationships between multiple variables at once, and a heatmap visualizes this matrix in a way that's easy to understand, with color gradients showing the strength and direction of each relationship. Without a heatmap, it would be tedious to grasp these relationships just from raw numbers. Also, using color coding with annotations (showing exact correlation coefficients) makes the interpretation faster and clearer for decision-making purposes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap provided several interesting insights. Firstly, duration_sec and duration_min showed a perfect positive correlation (close to 1.00), which makes sense since duration_min is simply duration_sec divided by 60. More importantly, age showed a mild negative correlation with trip duration — meaning younger riders tend to have longer trip durations compared to older users. Meanwhile, start_hour showed very weak or almost no strong correlation with either age or duration, suggesting that the hour when a trip starts is relatively independent of how old the rider is or how long they ride. These insights suggest that while some variables are strongly related (duration measures), others are mostly independent.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely. Understanding correlations helps the business in two ways: first, it helps prevent redundancy in future modeling efforts — for example, since duration_sec and duration_min are perfectly correlated, we can drop one to simplify models without losing information. Secondly, understanding that age has a mild negative correlation with trip duration suggests that targeting younger riders with longer ride promotions (e.g., day passes, scenic ride packages) could be effective. Moreover, knowing that start hour doesn’t strongly correlate with age or duration implies that time-of-day promotions can be made universal rather than age-specific. These insights improve both operational efficiency and marketing effectiveness, leading to a better user experience and stronger revenue opportunities.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Chart - 15: Pair Plot of Key Features

sns.pairplot(df[['duration_min', 'start_hour', 'age']], diag_kind='kde')
plt.suptitle('Pair Plot of Key Numerical Features', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pair plot because it’s one of the most effective visualizations for exploring relationships between multiple continuous variables at once. Here, the variables duration_min, start_hour, and age were selected. A pair plot not only shows scatter plots between each pair of variables but also displays the distribution (via KDE or histograms) for each individual variable along the diagonal. This makes it easier to spot correlations, outliers, clustering, or any patterns in a single glance, without needing to create separate plots for each pair. It’s a very comprehensive and compact way to conduct preliminary data exploration.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot revealed several key insights. First, the scatter plot between age and duration_min reconfirmed a weak negative relationship, showing that younger users tend to have slightly longer ride durations, though with considerable variation. Also, from the start_hour scatter plots, there seemed to be a slight pattern where rides were more clustered around certain hours like morning (8-10 AM) and evening (5-7 PM), confirming the commuting behavior during peak hours. The distribution plots along the diagonal further showed that most trip durations are relatively short (heavily skewed toward shorter rides), most rides start during working hours, and that the user age distribution is concentrated around young adults and middle-aged individuals. No strong linear correlations were visible across all features, but there were clusters and patterns that are valuable for deeper modeling or segmentation work.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely. These visual insights help the business tailor strategies in several ways. Knowing that rides cluster around specific hours suggests opportunities for dynamic pricing — for example, offering promotions during off-peak hours to spread usage more evenly. Understanding that younger riders slightly prefer longer rides might influence product offerings like hourly passes, day trips, or leisure routes targeted at this demographic. The ride duration and age distributions also help when planning marketing campaigns — younger riders can be enticed with adventure or exploration themes, while slightly older riders may prefer commuting efficiency or fitness benefits. Additionally, since the scatterplots revealed that trips are concentrated around certain hours and age groups, resource allocation such as bike availability and maintenance scheduling can be fine-tuned to these high-demand periods, improving operational efficiency and user satisfaction.

# %% [markdown]
# #### Chart - 16

# %%
# Chart - 16: Bike Share for All Program Participation

sns.countplot(x='bike_share_for_all_trip', hue='user_type', data=df, palette='pastel')
plt.title('Bike Share for All Program Participation')
plt.xlabel('Participation')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a count plot for this chart because "bike_share_for_all_trip" is a categorical variable (yes/no), and we need to show how many users participated in this program, segmented by user type (customer or subscriber). A count plot clearly displays frequency counts for each category, making it easy to compare and interpret visually. Adding the "user_type" hue introduces a second layer of comparison without cluttering the chart. This makes it easier for decision-makers to see at a glance how different user types engage with the Bike Share for All program — a critical program for accessibility and inclusivity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart revealed that the majority of users, particularly subscribers, did not participate in the Bike Share for All Program. However, a notable proportion of customers were part of this program compared to subscribers. This suggests that the program is more popular among casual or non-commuter riders rather than regular subscribers. Additionally, while the participation numbers aren't huge overall, there is clear evidence that the program is serving its purpose by attracting a different segment of the population — likely those needing more affordable, accessible options for short-term or casual rides.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely. Understanding participation in the Bike Share for All Program is crucial for both operational decisions and social responsibility goals. Since participation among customers is higher, the company can target this group more effectively with marketing campaigns — for example, promoting affordable ride options in lower-income communities or during community outreach events. Moreover, seeing that subscriber participation is lower could indicate an opportunity to redesign or better communicate the benefits of the program to a broader user base. Improving accessibility and affordability strengthens the brand image, fulfills corporate social responsibility (CSR) initiatives, and potentially opens up new markets. Strategically expanding the program, especially in underserved areas, could also help increase ridership numbers overall, leading to higher revenue in the long term while building a strong, positive public reputation.

# %% [markdown]
# #### Chart - 17

# %%
# Chart - 17: Age Group Distribution

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


current_year = pd.to_datetime('now').year
if 'age' not in df.columns:
    df['age'] = current_year - df['member_birth_year']


def assign_age_group(age):
    if age < 20:
        return 'Teenager'
    elif 20 <= age < 30:
        return '20s'
    elif 30 <= age < 40:
        return '30s'
    elif 40 <= age < 50:
        return '40s'
    elif 50 <= age < 60:
        return '50s'
    else:
        return '60+'

df['age_group'] = df['age'].apply(assign_age_group)

plt.figure(figsize=(12, 7))
ax = sns.countplot(
    x='age_group', 
    hue='age_group',     
    data=df, 
    order=['Teenager', '20s', '30s', '40s', '50s', '60+'],
    palette='bright',
    legend=False         
)

plt.title('Age Group Distribution', fontsize=16, fontweight='bold')
plt.xlabel('Age Group', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a count plot (bar chart) for this visualization because "age group" is a categorical variable with distinct ranges (e.g., 18–25, 26–35, etc.). Bar charts are highly effective for showing the distribution of counts across different categories, making it easy to quickly see which age groups are most represented among the riders. Additionally, by manually assigning different colors to each bar, the chart became visually more attractive and made it easier to distinguish between age groups at a glance. This method ensures that the data remains organized, easy to interpret, and visually engaging for business users and stakeholders.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart revealed that the majority of riders fall into the younger to middle-aged categories, especially the 26–35 age group, which had the highest count. The 18–25 and 36–45 age groups also had significant representation, though slightly lower. As the age groups increased beyond 45, there was a noticeable drop in rider numbers. This indicates that the bike-sharing service is primarily used by younger adults and middle-aged individuals, while senior citizens (55+) are underrepresented. This usage trend could reflect physical comfort levels, lifestyle choices, or promotional efforts that are better aligned with younger demographics.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely. Knowing the primary age groups helps businesses tailor their marketing strategies, service designs, and customer experience improvements more accurately. Since the service is mostly used by individuals aged 18–45, marketing campaigns can target this group with messages related to convenience, eco-friendliness, fitness, and urban mobility. Additionally, promotions could be created to appeal to younger riders such as student discounts or adventure route packages. At the same time, the noticeable underrepresentation of older age groups presents an opportunity — the company could develop initiatives to make the service more accessible and appealing to older customers, such as offering electric bike options or safety-focused training sessions. By targeting both strengths (dominant age groups) and gaps (older age groups), the business can expand its user base, improve customer loyalty, and generate new revenue streams, all while positioning itself as an inclusive transportation service.

# %% [markdown]
# #### Chart - 18

# %%
# Chart - 18: Trip Count by Start Hour and User Type

plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='start_hour', hue='user_type', multiple='stack', palette='husl')
plt.title('Trip Count by Hour and User Type')
plt.xlabel('Hour')
plt.ylabel('Trip Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For this analysis, I selected a histogram with stacking by user type because we were dealing with a continuous variable (start_hour) and needed to compare how the trip counts vary across different times of the day, separated by user_type (Customer or Subscriber). A stacked histogram is perfect for visualizing the volume of trips at different hours while simultaneously highlighting the contribution of each user type without crowding the visual space. It allows easy detection of peak times and differences in behavior between user types across the daily cycle — information that’s critical for operations and marketing teams alike.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart clearly showed two major peak periods: one in the morning around 8 AM and another in the evening around 5-6 PM. This behavior strongly indicates that many riders are using the service for commuting purposes, matching common work and school schedules. Interestingly, the chart also showed that subscribers dominated during these peak commuting hours, while customers (more casual riders) were more spread out and had slight activity during off-peak hours, like late mornings and afternoons. This highlights a pattern: subscribers use bikes mainly for daily commuting needs, whereas customers ride bikes more for leisure or occasional needs. Furthermore, very early mornings and late nights showed minimal activity, suggesting that the bike service has little to no usage during those hours.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely. These insights directly guide multiple strategic areas. Operationally, the company can ensure more bike availability and bike maintenance coverage around morning and evening rush hours to meet commuter demands. Knowing that subscribers dominate during peak hours, targeted loyalty programs like free minutes during peak time or incentives for regular commuting could be launched. For customers who ride during off-peak times, special leisure or tourism packages could be designed, such as discounted day passes or guided bike tours. Additionally, marketing campaigns can be scheduled to match user activity patterns — pushing commuter messaging early in the morning and leisure messaging in the afternoon. Optimizing service and promotions based on these detailed time-of-day and user-type behaviors leads to better resource allocation, improved rider satisfaction, and ultimately stronger revenues and customer loyalty.

# %% [markdown]
# #### Chart - 19

# %%
# Chart - 19: Duration by Gender and User Type

plt.figure(figsize=(10, 6))
sns.boxplot(x='member_gender', y='duration_min', hue='user_type', data=df)
plt.ylim(0, 60)
plt.title('Trip Duration by Gender and User Type')
plt.xlabel('Gender')
plt.ylabel('Trip Duration (min)')
plt.legend(title='User Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a box plot for this chart because we wanted to compare trip duration distributions across two categorical variables: member_gender and user_type. A box plot is excellent for displaying the central tendency (median), spread (interquartile range), and presence of outliers in numerical data. It not only shows the average behavior but also highlights variations and anomalies. Using hue='user_type' further allowed us to differentiate between subscribers and customers within each gender category without making the chart look cluttered. The box plot also naturally restricts the y-axis to a reasonable range (here, 0–60 minutes), making comparisons very clear and visually impactful.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Several interesting insights emerged from the box plot. First, across all genders (Male, Female, and Other/Unknown), customers consistently had longer trip durations compared to subscribers. This is logical because subscribers often use the bikes for quick, efficient commuting, while customers might be using the service more for leisure rides, resulting in longer durations. Among genders, the duration spread was wider for customers across all categories, meaning customer trip lengths vary more significantly. Additionally, while male and female riders showed relatively similar trip durations on average, riders classified under "Other/Unknown" showed a wider variation — possibly due to a smaller sample size or different usage patterns. Outliers were also present, indicating that a few users had extremely long trip durations, although they were not common.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely. These insights allow the business to customize services and promotions based on user behavior. Knowing that customers have longer ride durations suggests that longer-term rental options or promotions (like 2-hour rental discounts) could be marketed specifically to this group. Meanwhile, for subscribers who typically take short rides, the business can offer subscription models that emphasize multiple short rides per day or added-value commuting features like bundled public transport access. Additionally, the fact that males and females have very similar average ride durations allows the business to design gender-neutral promotions without worrying about major behavioral differences. For the "Other/Unknown" gender group, further analysis and possibly special engagement campaigns could help understand and better serve this smaller but potentially important segment. Overall, by aligning service offerings with actual user behavior patterns, the business can enhance user satisfaction, increase ridership, and ultimately boost both revenue and brand loyalty.

# %% [markdown]
# #### Chart - 20

# %%
# Chart - 20: Weekly Usage Trend

weekly_trips = df.groupby('start_date').size()
weekly_trips.plot(kind='line', figsize=(12, 5), color='tomato')
plt.title('Weekly Usage Trend')
plt.xlabel('Date')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a line plot for this visualization because we are dealing with time series data — specifically, the number of bike trips per date (start_date). A line plot is the most effective way to show trends over time, making it easy to spot increases, decreases, seasonality, or irregular patterns. It visually connects data points across dates, allowing the viewer to observe fluctuations and general movement trends in a smooth, continuous way. Setting the figure size appropriately and rotating the x-axis labels ensures that the chart remains readable, even if there are many data points. This setup provides a clear picture of how user activity changes week by week.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The line plot revealed several important trends. There was a clear weekly pattern in bike usage, with regular peaks and dips — suggesting that bike usage likely increases during weekdays and drops during weekends (or vice versa depending on the customer base). Additionally, the overall trend showed some periods of rising trip counts and other periods where usage slightly dropped, potentially aligning with weather patterns, holidays, or academic calendars. There might also be some noticeable seasonal effects — such as increased usage during warmer months or tourist seasons if the data spans multiple months. Sudden sharp drops on specific dates could point to external factors like bad weather, holidays, or special events impacting ridership. Overall, the chart indicated that while bike usage fluctuates week to week, there is a relatively strong, consistent demand over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely. Understanding weekly and seasonal usage trends allows the business to plan better and operate more efficiently. For example, if bike usage consistently peaks during certain weeks or months, the company can ensure that more bikes are available, better maintenance schedules are in place, and customer service teams are prepared for higher demand. If drops are seen during specific periods (like during winter months or major holidays), promotional campaigns (such as discounted winter riding passes) could be launched to stimulate demand. Moreover, forecasting future demand based on these patterns can help the company optimize resource allocation, avoid shortages during busy periods, and manage costs more effectively during slow periods. Long-term planning such as expansion to new neighborhoods or adjusting subscription models can also be informed by these trends. Ultimately, turning data insights into strategic actions based on weekly usage trends will directly contribute to higher operational efficiency, improved customer satisfaction, and increased profitability.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# ####  Understanding the Business Objective
#
# The main objective for the Ford GoBike Sharing Service is to **increase user engagement, grow the customer base, improve operational efficiency, and boost profitability**.
#
# By deeply analyzing the Ford GoBike data through various charts (trip duration, age, gender, user type, start/end times, popular stations, etc.), we can recommend several strategies that directly support these goals.
#
# ---
#
# #### Suggested Strategies to Achieve the Business Objective
#
# ---
#
# #### 1. **User Segmentation and Personalized Marketing**
#
# - **Focus on Age Groups**:
#   Target riders aged 20-40 years with campaigns promoting fitness, eco-friendliness, and cost-effective commuting.
#
# - **Expand to Older Age Groups**:
#   Introduce e-bikes, senior discounts, and safety workshops to attract users aged 50+.
#
# - **Gender-Inclusive Campaigns**:
#   Develop programs promoting safety, launch women-only riding events, and collaborate with women's organizations to balance the gender distribution.
#
# ---
#
# #### 2. **Operational Optimization Based on Usage Patterns**
#
# - **Peak Hours Resource Allocation**:
#   Increase bike availability around 8 AM and 5-6 PM to support commuter traffic.
#
# - **Weekend Planning for Casual Riders**:
#   Place more bikes near parks and tourist areas to cater to weekend customer surges.
#
# - **Station Expansion Based on Demand**:
#   Expand docking stations at high-demand areas to avoid congestion and improve user experience.
#
# ---
#
# #### 3. **Loyalty Programs and Pricing Strategies**
#
# - **Subscriber Loyalty Programs**:
#   Offer free ride credits, exclusive perks, or discounts with local businesses for frequent riders.
#
# - **Flexible Plans for Customers**:
#   Create hourly rental packages or day-passes targeting tourists and casual users.
#
# - **Dynamic Pricing Based on Demand**:
#   Apply higher rates during peak times and offer off-peak discounts to balance usage.
#
# ---
#
# #### 4. **Technology and Data-Driven Improvements**
#
# - **Predictive Analytics**:
#   Implement machine learning to predict bike demand and automate rebalancing and maintenance scheduling.
#
# - **Mobile App Enhancements**:
#   Add live bike tracking, route suggestions, reservation options, and gamified rewards.
#
# - **Customer Feedback System**:
#   Collect real-time feedback to continuously improve service quality and customer satisfaction.
#
# ---
#
# #### 5. **Community Engagement and Corporate Social Responsibility (CSR)**
#
# - **Expand "Bike Share for All" Program**:
#   Partner with local governments and nonprofits to promote affordable bike-sharing options for underserved communities.
#
# - **Environmental Campaigns**:
#   Market the environmental benefits of biking to position Ford GoBike as a green city leader.
#
# - **Partnerships with Employers and Universities**:
#   Develop corporate and educational memberships to lock in consistent, long-term user bases.
#
# ---
#
# ### Final Recommendation
#
# By applying these strategies, Ford GoBike can **boost engagement, attract new user segments, optimize operations, and enhance its brand reputation**.
#
# Investments in **personalized marketing, operational excellence, dynamic pricing models, technology upgrades, and community outreach** will result in **higher revenues, greater customer loyalty, and sustainable growth** in the bike-sharing market.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# #### Key Insights Gathered
#
# - **Age and Usage Patterns**:
#   The majority of users are young adults (20-40 years), with relatively fewer older riders. This insight suggests a strong market among working professionals and students, but also reveals an opportunity to target older demographics through special initiatives.
#
# - **Gender Disparities**:
#   Male users dominate the platform. Female and "Other" gender groups are underrepresented. Safety improvements, targeted marketing, and inclusive community engagement can address this imbalance.
#
# - **User Type Behavior**:
#   Subscribers use the service primarily during weekday peak hours for commuting, whereas customers often ride during weekends and take longer trips, indicating leisure-focused usage.
#
# - **Station Demand Clustering**:
#   Certain stations are disproportionately popular, leading to the need for targeted station expansion, maintenance, and rebalancing efforts.
#
# - **Trip Duration and Program Participation**:
#   Customers take longer rides than subscribers. The "Bike Share for All" program is positively impacting casual users but has room for growth among subscribers.
#
# - **Temporal Usage Trends**:
#   Strong commuting patterns during morning and evening hours, with lighter usage late at night. Weekly and seasonal trends also impact ridership volume.
#
# #### Strategic Recommendations
#
# Based on the analysis, the following strategies are proposed:
#
# - **Personalized marketing** to age groups and genders to attract a broader and more diverse user base.
# - **Operational optimization** around peak commuting hours and weekends to maximize bike availability and service efficiency.
# - **Expansion of popular stations** and smarter rebalancing of bikes to meet user demands in high-traffic areas.
# - **Flexible pricing models** such as dynamic pricing during off-peak hours and special offers for leisure riders.
# - **Technology upgrades** including predictive analytics for demand forecasting, improved mobile apps, and gamification of the rider experience.
# - **Stronger CSR efforts** through community outreach, environmental campaigns, and partnerships with local organizations.
#
# Implementing these strategies will help the business adapt to its customer base, enhance rider satisfaction, and ultimately drive sustainable growth.
#
# ####  Overall Business Impact
#
# If these solutions are implemented successfully, the expected business impacts include:
#
# - **Higher User Retention**:
#   By improving the commuter experience and offering personalized loyalty programs, more subscribers will stay engaged long-term.
#
# - **Market Expansion**:
#   Targeted campaigns toward underrepresented groups (older riders, women, and low-income users) will unlock new market segments.
#
# - **Revenue Growth**:
#   Flexible and dynamic pricing models will increase monetization opportunities, and corporate partnerships will guarantee stable, recurring income.
#
# - **Operational Efficiency**:
#   Data-driven rebalancing and maintenance will optimize costs and ensure higher service reliability.
#
# - **Stronger Brand Reputation**:
#   Inclusive initiatives and environmental leadership will boost public image, making Ford GoBike not just a transportation service, but a positive force within the community.
#
# #### Final Thoughts
#
# The bike-sharing industry is dynamic, competitive, and rapidly evolving. Companies like Ford GoBike must leverage data insights to stay ahead. This project shows that **data-driven decision-making** can reveal clear opportunities to enhance user satisfaction, optimize operations, expand reach, and grow revenue.
#
# By embracing the recommended strategies, Ford GoBike is well-positioned to transform itself into a more resilient, inclusive, and highly profitable urban mobility leader.
